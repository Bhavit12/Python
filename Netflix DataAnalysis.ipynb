# %% [markdown]
# # Netflix Data Analysis

# %%
#Import All Libraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('8. Netflix Dataset.csv')

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.size
# Out:
# 85679

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
[x for x in df.columns if df[x].isnull().sum()>0]
# Out:
# ['Director', 'Cast', 'Country', 'Release_Date', 'Rating']

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %% [markdown]
# # For 'House of cards' , whats is the show id and who is the director of this show?

# %%
df[df['Title'].isin(['House of Cards'])]     # Using isin Function
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].str.contains('House of Cards')]    # using str.contains
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Release_Date'].isin(['June 30, 2020'])]
# Out:
#      Show_Id Category                               Title      Director  \
# 2377   s2378    Movie  George Lopez: We'll Do It For Half   Troy Miller
# 6678   s6677    Movie                      The Mirror Boy  Obi Emelonye
#
#                                                    Cast  \
# 2377                                       George Lopez
# 6678  Edward Kagutuzi, Genevieve Nnaji, Osita Iheme,...
#
#                       Country   Release_Date Rating Duration  \
# 2377            United States  June 30, 2020  TV-MA   52 min
# 6678  United Kingdom, Nigeria  June 30, 2020  TV-14   86 min
#
#                                                   Type  \
# 2377                                   Stand-Up Comedy
# 6678  Action & Adventure, Dramas, International Movies
#
#                                             Description
# 2377  Comedian George Lopez tackles the future and t...
# 6678  A young boy is taken to his mother's birth hom...

# %% [markdown]
# # Q2 . In which year highest no. of the TV Shows & Movies were released ? Show with bar graph

# %%
df['date']=pd.to_datetime(df['Release_Date'])     # to_datetime

# %%
dateyear=df['date'].dt.year.value_counts()

# %%
dateyear
# Out:
# 2019    1337
# 2020    1229
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: date, dtype: int64

# %%
df['date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q3. How many movies & tv shows are in the dataset? show with the bar graph.

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
df['Category'].value_counts()
# Out:
# Movie      4673
# TV Show     136
# Name: Category, dtype: int64

# %%
df['Category'].value_counts().plot(kind='bar')   # using Value_count function
# Out:
# <AxesSubplot:>

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      4673
# TV Show     136
# Name: Category, dtype: int64

# %%
sns.countplot(df['Category'])
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# # Q4. Show all the movies that were released in 2020.

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
df['year']=df['date'].dt.year

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       date  year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
df[(df['year']==2020) & (df['Category']=='Movie')]
# Out:
#      Show_Id Category                          Title  \
# 4         s5    Movie                             21
# 6         s7    Movie                            122
# 14       s15    Movie                           3022
# 27       s28    Movie                         #Alive
# 28       s29    Movie  #AnneFrank - Parallel Stories
# ...      ...      ...                            ...
# 7746   s7745    Movie    Yours Sincerely, Kanan Gill
# 7750   s7749    Movie                      الف مبروك
# 7762   s7761    Movie                      Zaki Chan
# 7783   s7782    Movie                           Zoom
# 7784   s7783    Movie                           Zozo
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...                           ...
# 7746                 Neville Shah
# 7750            Ahmed Nader Galal
# ...

# %% [markdown]
# # Q5. show only the titles of all the TV Shows that were released in India.

# %%
df[(df['Category']=='TV Show') & (df['Country']== 'India')]['Title']
# Out:
# 132                                 7 (Seven)
# 2406                                    GHOUL
# 3119             Jamtara - Sabka Number Ayega
# 4724                          Paava Kadhaigal
# 6037    Th Eena Meena Deeka Chase Comedy Show
# Name: Title, dtype: object

# %% [markdown]
# # Q6. Show top 10 directors who gave the highest number of Tv shows & Movies to Netflix

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %% [markdown]
# # Q7 Show all the records , where "Category" is Movie and Type is "Comedies" or "Country" is United Kingdom

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       date  year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
df[(df['Category']=="Movie" ) & (df['Type']=='Comedies') | (df['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                       Title  \
# 33       s34    Movie                #realityhigh
# 72       s73    Movie                    17 Again
# 82       s83    Movie         2036 Origin Unknown
# 84       s85    Movie                   21 & Over
# 93       s94    Movie           27: Gone Too Soon
# ...      ...      ...                         ...
# 7615   s7614    Movie  Why Are We Getting So Fat?
# 7623   s7622    Movie                   Wild Oats
# 7634   s7633    Movie                Wine Country
# 7664   s7663    Movie                     Work It
# 7725   s7724    Movie                You Can Tutu
#
#                                     Director  \
# 33                          Fernando Lebrija
# 72                               Burr Steers
# 82                             Hasraf Dulull
# 84                    Jon Lucas, Scott Moore
# 93                         Simon Napier-Bell
# ...                                      ...
# ...

# %% [markdown]
# # Q8. In how many movies/ shows, Tom Cruise was Cast?

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       date  year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
df[df['Cast']=="Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, date, year]
# Index: []

# %%
df[df['Cast'].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       date  year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %% [markdown]
# # Q9 . What are the diffrent Ratings defined by Netflix?

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       date  year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # Q 9.1 How many movies got the 'TV-14'Rating , in Canada?

# %%
df[(df['Category']=="Movie")&(df['Rating']=='TV-14') & (df['Country']=='Canada')].shape
# Out:
# (9, 13)

# %% [markdown]
# # Q 9.2 How many Tv shows got the 'R' rating , after year 2018?

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       date  year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
df[(df['Category']=="TV Show")&(df['Rating']=='R') & (df['year']>2018)].shape
# Out:
# (0, 13)

# %% [markdown]
# # Q10. What is the maximum duration of a movie/shows on netflix?

# %%
df[["Minute" , " Units"]] =df['Duration'].str.split(' ' , expand= True)

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       date  year Minute  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016     93
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018     78
#
#    Units
# 1    min
# 2    min

# %%
df.Duration.max()
# Out:
# '99 min'

# %%
df['Duration'].unique().max()
# Out:
# '99 min'

# %%
df.Minute.min()
# Out:
# '1'

# %% [markdown]
# # Q 11. Which Individual Country has highest no. of TV Shows?

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       date  year Minute  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016     93
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018     78
#
#    Units
# 1    min
# 2    min

# %%
df_tvshow=df[df['Category']=='TV Show']

# %%
df_tvshow.head(2)
# Out:
#     Show_Id Category      Title     Director  \
# 5        s6  TV Show         46  Serdar Akar
# 132    s133  TV Show  7 (Seven)  Nizar Shafi
#
#                                                   Cast Country   Release_Date  \
# 5    Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey   July 1, 2017
# 132  Rahman, Havish, Regina Cassandra, Nandita Swet...   India  July 30, 2019
#
#     Rating  Duration                                             Type  \
# 5    TV-MA  1 Season  International TV Shows, TV Dramas, TV Mysteries
# 132  TV-14  1 Season                                         TV Shows
#
#                                            Description       date  year  \
# 5    A genetics professor experiments with a treatm... 2017-07-01  2017
# 132  Multiple women report their husbands as missin... 2019-07-30  2019
#
#     Minute   Units
# 5        1  Season
# 132      1  Season

# %%
df_tvshow.Country.value_counts().head(2)
# Out:
# United States     27
# United Kingdom    19
# Name: Country, dtype: int64

# %% [markdown]
# # Q12. How can we Sort the dataset by years?

# %%
df['year'].sort_values(ascending=False).head()
# Out:
# 2269    2021
# 2349    2021
# 6248    2021
# 1673    2021
# 7147    2021
# Name: year, dtype: int64

# %%
df.sort_values(by='year',ascending=False).head(3)
# Out:
#      Show_Id Category               Title                         Director  \
# 2269   s2270    Movie          Fred Claus                     David Dobkin
# 2349   s2350    Movie           Gangaajal                      Prakash Jha
# 6248   s6248    Movie  The Creative Brain  Jennifer Beamish, Toby Trackman
#
#                                                    Cast        Country  \
# 2269  Vince Vaughn, Paul Giamatti, John Michael Higg...  United States
# 2349  Ajay Devgn, Gracy Singh, Mohan Agashe, Mohan J...          India
# 6248                                     David Eagleman  United States
#
#          Release_Date Rating Duration                                Type  \
# 2269  January 1, 2021     PG  115 min  Children & Family Movies, Comedies
# 2349  January 8, 2021  TV-MA  148 min        Dramas, International Movies
# 6248  January 1, 2021  TV-14   53 min                       Documentaries
#
#                                             Description       date  year  \
# ...

# %% [markdown]
# # .............................................................
